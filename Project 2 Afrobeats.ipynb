# %%
import pandas as pd
import requests

# %%
#Refresh Token: KhFh4xkTLk5BSE9wwbambqba6OfkPhPcjyBmiVyl98o3wvw6LJF4EvFr5f2V3yrj

# %%
from requests import get, post
from sys import exit
from pprint import pprint

# %%
HOST = 'https://api.chartmetric.com'
TOKEN = 'KhFh4xkTLk5BSE9wwbambqba6OfkPhPcjyBmiVyl98o3wvw6LJF4EvFr5f2V3yrj'
res = post(f'{HOST}/api/token', json={"refreshtoken": TOKEN})
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/token')
    exit(1)

access_token = res.json()['token']
def Get(uri):
    return get(f'{HOST}{uri}', headers={'Authorization': f'Bearer {access_token}'})

res = Get('/api/charts/spotify?date=2024-01-01&country_code=global&interval=daily&type=regional')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'data': [{'added_at': '2024-01-01T00:00:00.000Z',
#                    'album': [{'id': 32315606,
#                               'label': 'Interscope Records',
#                               'name': 'La Diabla - Single',
#                               'release_date': '2023-12-02',
#                               'upc': '196922729812'}],
#                    'album_ids': [32315606],
#                    'album_label': ['Interscope Records'],
#                    'album_names': ['La Diabla - Single'],
#                    'album_upc': ['196922729812'],
#                    'artist_covers': [None],
#                    'artist_images': ['https://i.scdn.co/image/ab6761610000e5ebf25379218c13e6aef1f1793d'],
#                    'artist_names': ['Xavi'],
#                    'artists': [{'career_stage': 'superstar',
#                                 'code2': 'US',
#                                 'id': 4128409,
# ...

# %%
res.json().keys()
# Out:
# dict_keys(['obj'])

# %%
#Top 50 global Songs at that time
global_24_01_01 = res.json()

# %%
global_24_01_01["obj"]["data"]
# Out:
# [{'id': 133476046,
#   'name': 'La Diabla',
#   'isrc': 'USA2P2357356',
#   'spotify_track_id': '0R6NfOiLzLj4O5VbYSJAjf',
#   'spotify_album_id': '2IoSjweCu07y9mv5H1Cj3v',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b2731501c770de50a22b25d67611',
#   'spotify_popularity': 86,
#   'cm_track': 114553723,
#   'spotify_artist_names': ['Xavi'],
#   'track_genre': None,
#   'cm_artist': [4128409],
#   'artist_names': ['Xavi'],
#   'code2s': ['US'],
#   'artist_images': ['https://i.scdn.co/image/ab6761610000e5ebf25379218c13e6aef1f1793d'],
#   'artist_covers': [None],
#   'spotify_artist_ids': ['3Me35AWHCGqW4sZ7bWWJt1'],
#   'spotify_track_ids': ['0R6NfOiLzLj4O5VbYSJAjf'],
#   'spotify_album_ids': ['2IoSjweCu07y9mv5H1Cj3v'],
#   'spotify_duration_ms': 172264,
#   'album_ids': [32315606],
#   'album_names': ['La Diabla - Single'],
#   'album_upc': ['196922729812'],
#   'album_label': ['Interscope Records'],
#   'release_dates': ['2023-11-30'],
#   'composer_name': None,
# ...

# %%
for genre in global_24_01_01["obj"]["data"]:
    print(genre["track_genre"])
# Out:
# None
# pop,social media pop
# pop
# deep underground hip hop,pop rap,underground hip hop
# art pop,brooklyn indie,chamber pop,escape room,folk-pop,indie pop
# None
# deep pop r&b,trap queen
# canadian contemporary r&b,canadian pop,pop,rap,k-pop
# baile pop,funk carioca,funk das antigas
# electropop,la indie,pop
# colombian pop,pop reggaeton,reggaeton,reggaeton flow,reggaeton,trap latino
# reggaeton
# regional mexican pop
# None
# brostep,progressive electro house,regional mexican pop
# None
# garage rock,modern rock,permanent wave,rock,sheffield indie
# modern rock,neo mellow,pop
# dance pop,pop,post-teen pop
# None
# reggaeton,regional mexican pop
# colombian pop,pop reggaeton,reggaeton,reggaeton flow
# dance pop,pop,canadian contemporary r&b,canadian pop,pop,rap,atl hip hop,hip hop,pop rap,rap,trap,underground hip hop
# regional mexican pop
# dance pop,pop,post-teen pop,uk pop
# electro,filter house,canadian contemporary r&b,canadian pop,pop,rap
# ...

# %%
from requests import get, post

# %%
import requests
import base64

# Your client ID and client secret
client_id = 'af2e230c19424b588d66c63674665587'
client_secret = '25f8b38cdf894d769add9f0117d3fba8'

# Encode the client ID and client secret
auth_str = f'{client_id}:{client_secret}'
b64_auth_str = base64.b64encode(auth_str.encode()).decode()

# Get the access token
auth_url = 'https://accounts.spotify.com/api/token'
auth_headers = {
    'Authorization': f'Basic {b64_auth_str}'
}
auth_data = {
    'grant_type': 'client_credentials'
}
auth_response = requests.post(auth_url, headers=auth_headers, data=auth_data)
auth_response_data = auth_response.json()
access_token = auth_response_data['access_token']

# Use the access token to make API requests
api_url = 'https://api.spotify.com/v1/recommendations/available-genre-seeds'
headers = {
    'Authorization': f'Bearer {access_token}'
}
params = {
    'market': 'US'
}
response = requests.get(api_url, headers=headers, params=params)
genres = response.json()

# Print the top tracks
print(genres)
# Out:
# {'genres': ['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient', 'anime', 'black-metal', 'bluegrass', 'blues', 'bossanova', 'brazil', 'breakbeat', 'british', 'cantopop', 'chicago-house', 'children', 'chill', 'classical', 'club', 'comedy', 'country', 'dance', 'dancehall', 'death-metal', 'deep-house', 'detroit-techno', 'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk', 'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove', 'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle', 'heavy-metal', 'hip-hop', 'holidays', 'honky-tonk', 'house', 'idm', 'indian', 'indie', 'indie-pop', 'industrial', 'iranian', 'j-dance', 'j-idol', 'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay', 'mandopop', 'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies', 'mpb', 'new-age', 'new-release', 'opera', 'pagode', 'party', 'philippines-opm', 'piano', 'pop', 'pop-film', 'post-dubste
# ...

# %%
#Getting the id of the Spotify Playlist "African Heat"
HOST = 'https://api.chartmetric.com'
TOKEN = 'KhFh4xkTLk5BSE9wwbambqba6OfkPhPcjyBmiVyl98o3wvw6LJF4EvFr5f2V3yrj'
res = post(f'{HOST}/api/token', json={"refreshtoken": TOKEN})
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/token')
    exit(1)

access_token = res.json()['token']
def Get(uri):
    return get(f'{HOST}{uri}', headers={'Authorization': f'Bearer {access_token}'})

res = Get('/api/search?q=https://open.spotify.com/playlist/37i9dQZF1DWYkaDif7Ztbp')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [],
#          'artists': [],
#          'cities': [],
#          'curators': {'amazon': [],
#                       'applemusic': [],
#                       'deezer': [],
#                       'spotify': [],
#                       'youtube': []},
#          'labels': [],
#          'playlists': {'amazon': [],
#                        'applemusic': [],
#                        'deezer': [],
#                        'spotify': [{'followers': '1.6M',
#                                     'id': 988385,
#                                     'image_url': 'https://i.scdn.co/image/ab67706f000000027f7731d7d80d56e030cd459a',
#                                     'name': 'African Heat',
#                                     'num_track': 50,
#                                     'owner_name': 'Spotify'}],
#                        'youtube': []},
#          'songwriters': [],
#          'stations': [],
#          'tracks': []}}

# %%
#Tracking the daily growth/decrease of the followers of the Spotify Playlist of "African Heat"
#Date is on format yyyy-mm-dd

res = Get('/api/playlist/spotify/988385/stats?since=2017-01-01&until=2024-07-14')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': [{'daily_diff': 0,
#           'id': 18754964,
#           'interpolated': False,
#           'timestp': '2017-01-01T00:00:00.000Z',
#           'value': 96015},
#          {'daily_diff': 161,
#           'id': 18766914,
#           'interpolated': False,
#           'timestp': '2017-01-02T00:00:00.000Z',
#           'value': 96176},
#          {'daily_diff': 199,
#           'id': 18778800,
#           'interpolated': False,
#           'timestp': '2017-01-03T00:00:00.000Z',
#           'value': 96375},
#          {'daily_diff': 191,
#           'id': 18842557,
#           'interpolated': False,
#           'timestp': '2017-01-04T00:00:00.000Z',
#           'value': 96566},
#          {'daily_diff': 263,
#           'id': 18866688,
#           'interpolated': False,
#           'timestp': '2017-01-05T00:00:00.000Z',
#           'value': 96829},
#          {'daily_diff': 254,
#           'id': 18888533,
#           'interpolated': False,
# ...

# %%
#Value is the variable that shows the total followers

#Now doing the same with other popular Afrobeats Playlist ("Afrobeats Hits")
#First looking for the ID

res = Get('/api/search?q=https://open.spotify.com/playlist/25Y75ozl2aI0NylFToefO5')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [],
#          'artists': [],
#          'cities': [],
#          'curators': {'amazon': [],
#                       'applemusic': [],
#                       'deezer': [],
#                       'spotify': [],
#                       'youtube': []},
#          'labels': [],
#          'playlists': {'amazon': [],
#                        'applemusic': [],
#                        'deezer': [],
#                        'spotify': [{'followers': '81K',
#                                     'id': 19238868,
#                                     'image_url': 'https://i2o.scdn.co/image/ab67706c0000cfa36e42bc5cdecb8affe7fffe01',
#                                     'name': 'Afrobeats Hits 🔥',
#                                     'num_track': 120,
#                                     'owner_name': 'EMA Records'}],
#                        'youtube': []},
#          'songwriters': [],
#          'stations': [],
#          'tracks': []}}

# %%
res = Get('/api/playlist/spotify/19238868/stats?since=2017-01-01&until=2024-07-14')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': [{'daily_diff': 0,
#           'id': 1260500264,
#           'interpolated': False,
#           'timestp': '2023-08-29T00:00:00.000Z',
#           'value': 2018},
#          {'daily_diff': 91,
#           'id': 1261764290,
#           'interpolated': False,
#           'timestp': '2023-08-30T00:00:00.000Z',
#           'value': 2109},
#          {'daily_diff': 95,
#           'id': 1262971065,
#           'interpolated': False,
#           'timestp': '2023-08-31T00:00:00.000Z',
#           'value': 2204},
#          {'daily_diff': 79,
#           'id': 1264262415,
#           'interpolated': False,
#           'timestp': '2023-09-01T00:00:00.000Z',
#           'value': 2283},
#          {'daily_diff': 92,
#           'id': 1265461088,
#           'interpolated': False,
#           'timestp': '2023-09-02T00:00:00.000Z',
#           'value': 2375},
#          {'daily_diff': 79,
#           'id': 1266706601,
#           'interpolated': False,
# ...

# %%
#Getting the id of the Spotify Playlist "Afropop"

res = Get('/api/search?q=https://open.spotify.com/playlist/37i9dQZF1DWYs2pvwxWA7l')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [],
#          'artists': [],
#          'cities': [],
#          'curators': {'amazon': [],
#                       'applemusic': [],
#                       'deezer': [],
#                       'spotify': [],
#                       'youtube': []},
#          'labels': [],
#          'playlists': {'amazon': [],
#                        'applemusic': [],
#                        'deezer': [],
#                        'spotify': [{'followers': '576K',
#                                     'id': 1660342,
#                                     'image_url': 'https://i.scdn.co/image/ab67706f0000000233c6f7507b7480d080579835',
#                                     'name': 'Afropop',
#                                     'num_track': 70,
#                                     'owner_name': 'Spotify'}],
#                        'youtube': []},
#          'songwriters': [],
#          'stations': [],
#          'tracks': []}}

# %%
#Growth of "Afropop" Playlist

res = Get('/api/playlist/spotify/1660342/stats?since=2017-01-01&until=2024-07-14')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': [{'daily_diff': 0,
#           'id': 25167864,
#           'interpolated': False,
#           'timestp': '2017-04-06T00:00:00.000Z',
#           'value': 7108},
#          {'daily_diff': -1,
#           'id': 25184729,
#           'interpolated': False,
#           'timestp': '2017-04-07T00:00:00.000Z',
#           'value': 7107},
#          {'daily_diff': -1,
#           'id': 25206573,
#           'interpolated': False,
#           'timestp': '2017-04-08T00:00:00.000Z',
#           'value': 7106},
#          {'daily_diff': -5,
#           'id': 25237065,
#           'interpolated': False,
#           'timestp': '2017-04-09T00:00:00.000Z',
#           'value': 7101},
#          {'daily_diff': -1,
#           'id': 25337121,
#           'interpolated': False,
#           'timestp': '2017-04-10T00:00:00.000Z',
#           'value': 7100},
#          {'daily_diff': -3,
#           'id': 25358389,
#           'interpolated': False,
# ...

# %%
#Getting the id of Spotify Playlist "Afro Hits"

res = Get('/api/search?q=https://open.spotify.com/playlist/37i9dQZF1DWX0o6sD6P51a')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [],
#          'artists': [],
#          'cities': [],
#          'curators': {'amazon': [],
#                       'applemusic': [],
#                       'deezer': [],
#                       'spotify': [],
#                       'youtube': []},
#          'labels': [],
#          'playlists': {'amazon': [],
#                        'applemusic': [],
#                        'deezer': [],
#                        'spotify': [],
#                        'youtube': []},
#          'songwriters': [],
#          'stations': [],
#          'tracks': []}}

# %%
#Growth of "Afro Hits" Playlist

res = Get('/api/playlist/spotify/983218/stats?since=2017-01-01&until=2024-07-14')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': [{'daily_diff': 0,
#           'id': 24487369,
#           'interpolated': False,
#           'timestp': '2017-03-28T00:00:00.000Z',
#           'value': 50130},
#          {'daily_diff': 94,
#           'id': 24645869,
#           'interpolated': False,
#           'timestp': '2017-03-29T00:00:00.000Z',
#           'value': 50224},
#          {'daily_diff': 95,
#           'id': 24724265,
#           'interpolated': False,
#           'timestp': '2017-03-30T00:00:00.000Z',
#           'value': 50319},
#          {'daily_diff': 234,
#           'id': 24802076,
#           'interpolated': False,
#           'timestp': '2017-03-31T00:00:00.000Z',
#           'value': 50553},
#          {'daily_diff': 268,
#           'id': 24964823,
#           'interpolated': False,
#           'timestp': '2017-04-01T00:00:00.000Z',
#           'value': 50821},
#          {'daily_diff': 571,
#           'id': 24987627,
#           'interpolated': False,
# ...

# %%
#Next: In what cities do people listen to certain artists?
#Doing this via YouTube (Chartmetrics) -> Top Countries of Afrobeats Artist

#According to Spotify https://afrobeats.byspotify.com/ these are the most streamed Afrobeats
# artists in 2023: Davido, Rema, Burna Boy, Ayra Starr, Asake, Libianka (??), Victony, Tempoe, Omah Lay, Wizkid
#I am gonna replace Libianka with Tems, bc a) she is not Afrobeats and b) Tems released a very successful album this year

#Getting the ID of Davido

res = Get('/api/search?q=Davido&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [{'artist_name': ['Chino'],
#                      'cm_artist': [25074],
#                      'id': 14257092,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b273a2ae968f9e003b09bf492425',
#                      'label': '953299 Records DK',
#                      'name': 'Davido'}],
#          'artists': [{'cm_artist_score': 85742,
#                       'id': 4723,
#                       'image_url': 'https://i.scdn.co/image/ab6761610000e5eb1ae40d4e47750c0ac367f993',
#                       'isni': '0000000462743379',
#                       'name': 'Davido',
#                       'sp_followers': 5117888,
#                       'sp_monthly_listeners': 8508083,
#                       'verified': False},
#                      {'cm_artist_score': None,
#                       'id': 732928,
#                       'image_url': None,
#                       'isni': None,
#                       'name': 'DaVido',
# ...

# %%
#Checking his Growth over the last five years
#First the current date in 2024
res = Get('/api/artist/4723/youtube-audience-stats?date=2024-07-15&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'female', 'weight': '37.84'},
#                               {'code': 'male', 'weight': '62.16'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '2.98',
#                                        'male': '1.99'},
#                                       {'code': '18-24',
#                                        'female': '19.76',
#                                        'male': '27.34'},
#                                       {'code': '25-34',
#                                        'female': '13.01',
#                                        'male': '28.71'},
#                                       {'code': '35-44',
#                                        'female': '1.79',
#                                        'male': '3.38'},
#                                       {'code': '45-64',
#                                        'female': '0.30',
# ...

# %%
davido_2024 = res.json()
davido_2024["obj"]["top_countries"]
# Out:
# [{'name': 'United States',
#   'code': 'us',
#   'percent': '19.72',
#   'subscribers': 794699},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '13.83', 'subscribers': 557421},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '8.32', 'subscribers': 335207},
#  {'name': 'France', 'code': 'fr', 'percent': '7.38', 'subscribers': 297542},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '5.51',
#   'subscribers': 222214},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '4.86',
#   'subscribers': 195849},
#  {'name': 'Tanzania', 'code': 'tz', 'percent': '4.02', 'subscribers': 161953},
#  {'name': 'Canada', 'code': 'ca', 'percent': '2.80', 'subscribers': 112989},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '2.62', 'subscribers': 105457},
#  {'name': 'Senegal', 'code': 'sn', 'percent': '2.43', 'subscribers': 97924},
#  {'name': 'Brazil', 'code': 'br', 'percent': '1.50', 'subscribers': 60260},
# ...

# %%
#Checking his Growth over the last five years
#Now checking 15.07.23

res = Get('/api/artist/4723/youtube-audience-stats?date=2023-07-15&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# ERROR: received a 401 instead of 200 from /api/artist/:id
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
davido_2023 = res.json()
davido_2023["obj"]["top_countries"]
# Out:
# [{'name': 'United States',
#   'code': 'us',
#   'percent': '21.29',
#   'subscribers': 749464},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '11.40', 'subscribers': 401371},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '8.48', 'subscribers': 298365},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '5.85',
#   'subscribers': 206015},
#  {'name': 'France', 'code': 'fr', 'percent': '4.64', 'subscribers': 163391},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '4.04',
#   'subscribers': 142077},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '3.94', 'subscribers': 138526},
#  {'name': 'Tanzania', 'code': 'tz', 'percent': '3.23', 'subscribers': 113664},
#  {'name': 'Canada', 'code': 'ca', 'percent': '3.23', 'subscribers': 113664},
#  {'name': 'Uganda', 'code': 'ug', 'percent': '2.83', 'subscribers': 99454},
#  {'name': 'Italy', 'code': 'it', 'percent': '1.82', 'subscribers': 63933},
# ...

# %%
davido_df = pd.DataFrame(davido_2023["obj"]["top_countries"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 davido_df = pd.DataFrame(davido_2023["obj"]["top_countries"])
#
# NameError: name 'davido_2023' is not defined

# %%
#Checking his Growth over the last five years
#Now checking 15.07.22
#Not possible -> Earliest capture since April 23

res = Get('/api/artist/4723/youtube-audience-stats?date=2023-04-01&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'male', 'weight': '61.30'},
#                               {'code': 'female', 'weight': '38.70'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '2.77',
#                                        'male': '2.34'},
#                                       {'code': '18-24',
#                                        'female': '20.69',
#                                        'male': '27.81'},
#                                       {'code': '25-34',
#                                        'female': '13.23',
#                                        'male': '27.64'},
#                                       {'code': '35-44',
#                                        'female': '1.78',
#                                        'male': '2.88'},
#                                       {'code': '45-64',
#                                        'female': '0.23',
# ...

# %%
#Getting the ID of Rema

res = Get('/api/search?q=Rema&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [{'artist_name': ['Matteo'],
#                      'cm_artist': [80304],
#                      'id': 3381919,
#                      'image_url': 'https://i.scdn.co/image/d3f3bf2b6c27e8abb0fe0fa4484cdc80921213a7',
#                      'label': 'Chinese Man Records',
#                      'name': 'Rema'},
#                     {'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37193285,
#                      'image_url': 'https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/55/ab/86/55ab86fb-e53d-b406-d44e-29e7e6aa09a3/artwork.jpg/160x160bb.jpg',
#                      'label': None,
#                      'name': 'REMEKÜL - Single'},
#                     {'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37192866,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b2730ff2e205e63a8f86d6cc7a61',
#                      'label': None,
# ...

# %%
#Remas ID: 1426518
#Checking his Growth over the last five years
#Now checking 15.07.24

res = Get('/api/artist/1426518/youtube-audience-stats?date=2024-07-15&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'female', 'weight': '34.65'},
#                               {'code': 'male', 'weight': '65.35'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '2.94',
#                                        'male': '2.66'},
#                                       {'code': '18-24',
#                                        'female': '18.57',
#                                        'male': '31.98'},
#                                       {'code': '25-34',
#                                        'female': '10.58',
#                                        'male': '26.16'},
#                                       {'code': '35-44',
#                                        'female': '2.08',
#                                        'male': '3.83'},
#                                       {'code': '45-64',
#                                        'female': '0.48',
# ...

# %%
rema_24 = res.json()
rema_24["obj"]["top_countries"]
# Out:
# [{'name': 'United States',
#   'code': 'us',
#   'percent': '13.91',
#   'subscribers': 581596},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '8.17', 'subscribers': 341455},
#  {'name': 'Brazil', 'code': 'br', 'percent': '6.01', 'subscribers': 251401},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '5.66', 'subscribers': 236391},
#  {'name': 'France', 'code': 'fr', 'percent': '5.66', 'subscribers': 236391},
#  {'name': 'India', 'code': 'in', 'percent': '5.48', 'subscribers': 228888},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '3.68',
#   'subscribers': 153840},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '3.68',
#   'subscribers': 153840},
#  {'name': 'Morocco', 'code': 'ma', 'percent': '2.78', 'subscribers': 116321},
#  {'name': 'Tanzania', 'code': 'tz', 'percent': '2.51', 'subscribers': 105064},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '2.33', 'subscribers': 97556},
# ...

# %%
#Now checking 16.07.23

res = Get('/api/artist/1426518/youtube-audience-stats?date=2023-07-16&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'female', 'weight': '35.09'},
#                               {'code': 'male', 'weight': '64.91'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '2.35',
#                                        'male': '2.79'},
#                                       {'code': '18-24',
#                                        'female': '19.73',
#                                        'male': '32.19'},
#                                       {'code': '25-34',
#                                        'female': '10.52',
#                                        'male': '26.10'},
#                                       {'code': '35-44',
#                                        'female': '1.91',
#                                        'male': '3.11'},
#                                       {'code': '45-64',
#                                        'female': '0.57',
# ...

# %%
rema_23 = res.json()
rema_23["obj"]["top_countries"]
# Out:
# [{'name': 'United States',
#   'code': 'us',
#   'percent': '14.89',
#   'subscribers': 524036},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '7.93', 'subscribers': 279255},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '7.35', 'subscribers': 258568},
#  {'name': 'France', 'code': 'fr', 'percent': '7.15', 'subscribers': 251676},
#  {'name': 'Brazil', 'code': 'br', 'percent': '6.86', 'subscribers': 241331},
#  {'name': 'India', 'code': 'in', 'percent': '5.39', 'subscribers': 189618},
#  {'name': 'Morocco', 'code': 'ma', 'percent': '3.04', 'subscribers': 106874},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '2.84',
#   'subscribers': 99982},
#  {'name': 'Tanzania', 'code': 'tz', 'percent': '2.74', 'subscribers': 96532},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '2.35',
#   'subscribers': 82741},
#  {'name': 'Uganda', 'code': 'ug', 'percent': '2.15', 'subscribers': 75848},
# ...

# %%
#Now checking 14.07.22

res = Get('/api/artist/1426518/youtube-audience-stats?date=2022-07-14&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'female', 'weight': '34.96'},
#                               {'code': 'male', 'weight': '65.04'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '3.17',
#                                        'male': '3.36'},
#                                       {'code': '18-24',
#                                        'female': '21.28',
#                                        'male': '34.56'},
#                                       {'code': '25-34',
#                                        'female': '9.52',
#                                        'male': '24.47'},
#                                       {'code': '35-44',
#                                        'female': '0.89',
#                                        'male': '2.28'},
#                                       {'code': '45-64',
#                                        'female': '0.11',
# ...

# %%
#Now checking 12.07.21

res = Get('/api/artist/1426518/youtube-audience-stats?date=2021-07-12&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'female', 'weight': '36.52'},
#                               {'code': 'male', 'weight': '63.48'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '3.51',
#                                        'male': '3.88'},
#                                       {'code': '18-24',
#                                        'female': '23.33',
#                                        'male': '35.65'},
#                                       {'code': '25-34',
#                                        'female': '8.95',
#                                        'male': '21.99'},
#                                       {'code': '35-44',
#                                        'female': '0.71',
#                                        'male': '1.67'},
#                                       {'code': '45-64',
#                                        'female': '0.02',
# ...

# %%
rema_22 = res.json()
rema_22["obj"]["top_countries"]
# Out:
# [{'name': 'United States',
#   'code': 'us',
#   'percent': '13.57',
#   'subscribers': 114265},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '12.80', 'subscribers': 107782},
#  {'name': 'France', 'code': 'fr', 'percent': '9.05', 'subscribers': 76177},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '8.76', 'subscribers': 73745},
#  {'name': 'Tanzania', 'code': 'tz', 'percent': '7.22', 'subscribers': 60779},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '4.33',
#   'subscribers': 36467},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '3.75', 'subscribers': 31605},
#  {'name': 'Morocco', 'code': 'ma', 'percent': '3.08', 'subscribers': 25932},
#  {'name': 'Brazil', 'code': 'br', 'percent': '2.69', 'subscribers': 22691},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '2.60',
#   'subscribers': 21881},
#  {'name': 'Uganda', 'code': 'ug', 'percent': '2.21', 'subscribers': 18639},
#  {'name': 'Spain', 'code': 'es', 'percent': '1.64', 'subscribers': 13776},
# ...

# %%
#Now checking 12.07.20
#Doesn't have data for 2020 -> Gets data starting in 2021

res = Get('/api/artist/1426518/youtube-audience-stats?date=2021-01-06&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [],
#          'audience_genders_per_age': [],
#          'commenters_genders': [],
#          'commenters_genders_per_age': [],
#          'commenters_top_countries': [],
#          'notable_subscribers': [],
#          'timestp': '2021-01-06',
#          'top_countries': []}}

# %%
#Getting the ID of Tems

res = Get('/api/search?q=Tems&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [{'artist_name': ['Kwobi Jones'],
#                      'cm_artist': [8140871],
#                      'id': 20166375,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b2732c7731eaeaf81e25a8e06d91',
#                      'label': 'Montiwa Ltd',
#                      'name': 'Tems'},
#                     {'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37215301,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b273714a7f6702e8ed1d1ca308bf',
#                      'label': None,
#                      'name': 'TEMPLE'},
#                     {'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37208240,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b273a7959048561d740252c286b8',
#                      'label': None,
#                      'name': 'Tem et fier'}],
#          'artists': [{'cm_artist_score': 76384,
# ...

# %%
#Tems ID is 1345060
#Now checking her top countries on YT as of today (16.07.24) or the next possible date
res = Get('/api/artist/1345060/youtube-audience-stats?date=2024-07-16&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'male', 'weight': '51.98'},
#                               {'code': 'female', 'weight': '48.02'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '2.90',
#                                        'male': '1.60'},
#                                       {'code': '18-24',
#                                        'female': '25.96',
#                                        'male': '22.30'},
#                                       {'code': '25-34',
#                                        'female': '16.43',
#                                        'male': '23.99'},
#                                       {'code': '35-44',
#                                        'female': '2.46',
#                                        'male': '3.60'},
#                                       {'code': '45-64',
#                                        'female': '0.27',
# ...

# %%
tems24top = res.json()

tems24top["obj"]["top_countries"]
# Out:
# [{'name': 'United States',
#   'code': 'us',
#   'percent': '35.34',
#   'subscribers': 326554},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '11.04', 'subscribers': 102048},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '8.23',
#   'subscribers': 76071},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '8.03', 'subscribers': 74216},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '4.42',
#   'subscribers': 40819},
#  {'name': 'France', 'code': 'fr', 'percent': '3.01', 'subscribers': 27830},
#  {'name': 'Uganda', 'code': 'ug', 'percent': '2.71', 'subscribers': 25047},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '2.31', 'subscribers': 21337},
#  {'name': 'Tanzania', 'code': 'tz', 'percent': '2.11', 'subscribers': 19481},
#  {'name': 'Brazil', 'code': 'br', 'percent': '1.81', 'subscribers': 16698},
#  {'name': 'Jamaica', 'code': 'jm', 'percent': '1.61', 'subscribers': 14843},
#  {'name': 'Canada', 'code': 'ca', 'percent': '1.51', 'subscribers': 13915},
# ...

# %%
#Now looking for Burna Boys ID

res = Get('/api/search?q=Burna_Boy&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [{'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37200359,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b273ee1da1a4c826532df23cf6c9',
#                      'label': None,
#                      'name': 'Burna Boy'}],
#          'artists': [{'cm_artist_score': 116243,
#                       'id': 212614,
#                       'image_url': 'https://i.scdn.co/image/ab6761610000e5eb2d405f4858ce3cd52d409c98',
#                       'isni': None,
#                       'name': 'Burna Boy',
#                       'sp_followers': 9335818,
#                       'sp_monthly_listeners': 16618273,
#                       'verified': False},
#                      {'cm_artist_score': 0,
#                       'id': 10809562,
#                       'image_url': None,
#                       'isni': None,
#                       'name': 'BURNA BOYS',
#                       'sp_followers': None,
# ...

# %%
#Burna's ID is 212614
#Now checking his top countries on YT as of today (16.07.24) or the next possible date
res = Get('/api/artist/212614/youtube-audience-stats?date=2024-07-16&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'male', 'weight': '61.96'},
#                               {'code': 'female', 'weight': '38.04'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '3.05',
#                                        'male': '2.28'},
#                                       {'code': '18-24',
#                                        'female': '20.58',
#                                        'male': '26.97'},
#                                       {'code': '25-34',
#                                        'female': '12.20',
#                                        'male': '28.17'},
#                                       {'code': '35-44',
#                                        'female': '1.79',
#                                        'male': '3.85'},
#                                       {'code': '45-64',
#                                        'female': '0.42',
# ...

# %%
burna24top = res.json()

burna24top["obj"]["top_countries"]
# Out:
# [{'name': 'United States',
#   'code': 'us',
#   'percent': '20.84',
#   'subscribers': 1012697},
#  {'name': 'France', 'code': 'fr', 'percent': '8.28', 'subscribers': 402237},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '8.28', 'subscribers': 402237},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '7.40',
#   'subscribers': 359649},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '6.72', 'subscribers': 326523},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '3.99',
#   'subscribers': 194020},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '3.99', 'subscribers': 194020},
#  {'name': 'Canada', 'code': 'ca', 'percent': '3.12', 'subscribers': 151432},
#  {'name': 'Uganda', 'code': 'ug', 'percent': '2.63', 'subscribers': 127769},
#  {'name': 'Jamaica', 'code': 'jm', 'percent': '2.04', 'subscribers': 99377},
#  {'name': 'Portugal', 'code': 'pt', 'percent': '1.95', 'subscribers': 94643},
# ...

# %%
#Now looking for Ayra Starrs ID

res = Get('/api/search?q=Ayra_Starr&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [],
#          'artists': [{'cm_artist_score': 118263,
#                       'id': 4200054,
#                       'image_url': 'https://i.scdn.co/image/ab6761610000e5eb368ea5a7f6e1b11e896c1fc0',
#                       'isni': None,
#                       'name': 'Ayra Starr',
#                       'sp_followers': 3144606,
#                       'sp_monthly_listeners': 29517160,
#                       'verified': False},
#                      {'cm_artist_score': 1,
#                       'id': 11107098,
#                       'image_url': None,
#                       'isni': None,
#                       'name': 'Ayra Starr',
#                       'sp_followers': None,
#                       'sp_monthly_listeners': None,
#                       'verified': False},
#                      {'cm_artist_score': 0,
#                       'id': 11491632,
#                       'image_url': None,
#                       'isni': None,
# ...

# %%
#Ayras ID is 4200054
#Now checking her top countries on YT as of today (16.07.24) or the next possible date
res = Get('/api/artist/4200054/youtube-audience-stats?date=2024-07-16&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'male', 'weight': '60.97'},
#                               {'code': 'female', 'weight': '39.03'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '2.71',
#                                        'male': '1.92'},
#                                       {'code': '18-24',
#                                        'female': '20.87',
#                                        'male': '26.21'},
#                                       {'code': '25-34',
#                                        'female': '13.62',
#                                        'male': '28.26'},
#                                       {'code': '35-44',
#                                        'female': '1.69',
#                                        'male': '3.99'},
#                                       {'code': '45-64',
#                                        'female': '0.13',
# ...

# %%
ayra24top = res.json()

ayra24top["obj"]["top_countries"]
# Out:
# [{'name': 'United States',
#   'code': 'us',
#   'percent': '19.68',
#   'subscribers': 399605},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '12.95', 'subscribers': 262852},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '9.19', 'subscribers': 186483},
#  {'name': 'France', 'code': 'fr', 'percent': '6.30', 'subscribers': 127873},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '4.81',
#   'subscribers': 97681},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '4.29',
#   'subscribers': 87026},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '3.24', 'subscribers': 65713},
#  {'name': 'Uganda', 'code': 'ug', 'percent': '2.62', 'subscribers': 53281},
#  {'name': 'Brazil', 'code': 'br', 'percent': '2.45', 'subscribers': 49728},
#  {'name': 'Portugal', 'code': 'pt', 'percent': '2.10', 'subscribers': 42623},
#  {'name': 'Canada', 'code': 'ca', 'percent': '1.75', 'subscribers': 35520},
# ...

# %%
#Now looking for Asakes ID

res = Get('/api/search?q=Asake&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [{'artist_name': ['Jaeyo'],
#                      'cm_artist': [771789],
#                      'id': 2089772,
#                      'image_url': 'https://i.scdn.co/image/e1de4d3293087890380070834f792c69d0a04be8',
#                      'label': 'Jaeyo',
#                      'name': 'Asake'},
#                     {'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37195131,
#                      'image_url': 'https://is1-ssl.mzstatic.com/image/thumb/Music211/v4/b3/a9/2f/b3a92f25-6aaa-c5e9-e9f4-d24768524fde/5063483718706_cover.jpg/160x160bb.jpg',
#                      'label': None,
#                      'name': 'Asaletli̇ Aşkim - Single'},
#                     {'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37205115,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b27390451aa293c773c19ae7b268',
#                      'label': None,
# ...

# %%
#Asakes ID is 1779041
#Now checking his top countries on YT as of today (16.07.24) or the next possible date
res = Get('/api/artist/1779041/youtube-audience-stats?date=2024-07-16&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'male', 'weight': '74.30'},
#                               {'code': 'female', 'weight': '25.70'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '1.53',
#                                        'male': '2.10'},
#                                       {'code': '18-24',
#                                        'female': '13.91',
#                                        'male': '31.80'},
#                                       {'code': '25-34',
#                                        'female': '9.23',
#                                        'male': '35.35'},
#                                       {'code': '35-44',
#                                        'female': '0.87',
#                                        'male': '4.41'},
#                                       {'code': '45-64',
#                                        'female': '0.16',
# ...

# %%
asake24top = res.json()

asake24top["obj"]["top_countries"]
# Out:
# [{'name': 'Nigeria', 'code': 'ng', 'percent': '20.26', 'subscribers': 253241},
#  {'name': 'United States',
#   'code': 'us',
#   'percent': '17.75',
#   'subscribers': 221840},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '10.53', 'subscribers': 131685},
#  {'name': 'France', 'code': 'fr', 'percent': '8.35', 'subscribers': 104335},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '6.48',
#   'subscribers': 81037},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '6.48', 'subscribers': 81037},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '3.00',
#   'subscribers': 37480},
#  {'name': 'Tanzania', 'code': 'tz', 'percent': '2.84', 'subscribers': 35453},
#  {'name': 'Uganda', 'code': 'ug', 'percent': '2.67', 'subscribers': 33427},
#  {'name': 'Canada', 'code': 'ca', 'percent': '2.35', 'subscribers': 29376},
#  {'name': 'Italy', 'code': 'it', 'percent': '1.86', 'subscribers': 23298},
# ...

# %%
#Now looking for Victony's ID

res = Get('/api/search?q=Victony&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [{'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37225332,
#                      'image_url': 'https://is1-ssl.mzstatic.com/image/thumb/Music116/v4/b3/dc/70/b3dc7004-4661-3a13-c2e0-9146d22e885f/3666820005136.png/160x160bb.jpg',
#                      'label': None,
#                      'name': 'Victory - Single'},
#                     {'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37224872,
#                      'image_url': 'https://is1-ssl.mzstatic.com/image/thumb/Music123/v4/f6/dc/48/f6dc48f1-c3c4-cc45-9088-e0b737f16644/artwork.jpg/160x160bb.jpg',
#                      'label': None,
#                      'name': 'Victory Crew 96'},
#                     {'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37225791,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b273b290aec3c7e0364520d75af2',
# ...

# %%
#Victony's ID is 3905071
#Now checking his top countries on YT as of today (16.07.24) or the next possible date
res = Get('/api/artist/3905071/youtube-audience-stats?date=2024-07-16&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'male', 'weight': '73.58'},
#                               {'code': 'female', 'weight': '26.42'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '1.84',
#                                        'male': '2.37'},
#                                       {'code': '18-24',
#                                        'female': '14.90',
#                                        'male': '33.68'},
#                                       {'code': '25-34',
#                                        'female': '8.72',
#                                        'male': '33.82'},
#                                       {'code': '35-44',
#                                        'female': '0.73',
#                                        'male': '3.25'},
#                                       {'code': '45-64',
#                                        'female': '0.23',
# ...

# %%
victony24top = res.json()

victony24top["obj"]["top_countries"]
# Out:
# [{'name': 'United States',
#   'code': 'us',
#   'percent': '18.13',
#   'subscribers': 100280},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '13.39', 'subscribers': 74066},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '11.21', 'subscribers': 61999},
#  {'name': 'France', 'code': 'fr', 'percent': '7.45', 'subscribers': 41194},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '4.51',
#   'subscribers': 24966},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '3.46',
#   'subscribers': 19140},
#  {'name': 'Uganda', 'code': 'ug', 'percent': '3.16', 'subscribers': 17476},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '2.86', 'subscribers': 15811},
#  {'name': 'Tanzania', 'code': 'tz', 'percent': '2.63', 'subscribers': 14563},
#  {'name': 'Brazil', 'code': 'br', 'percent': '2.48', 'subscribers': 13731},
#  {'name': 'Portugal', 'code': 'pt', 'percent': '2.33', 'subscribers': 12899},
#  {'name': 'Canada', 'code': 'ca', 'percent': '2.11', 'subscribers': 11650},
# ...

# %%
#Now looking for Omah Lay's ID

res = Get('/api/search?q=Omah_Lay&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [],
#          'artists': [{'cm_artist_score': 68850,
#                       'id': 3578130,
#                       'image_url': 'https://i.scdn.co/image/ab6761610000e5ebbb683de126b7875921b44a54',
#                       'isni': None,
#                       'name': 'Omah Lay',
#                       'sp_followers': 2888800,
#                       'sp_monthly_listeners': 10406138,
#                       'verified': False},
#                      {'cm_artist_score': 0,
#                       'id': 8286764,
#                       'image_url': None,
#                       'isni': None,
#                       'name': 'Omah Lay',
#                       'sp_followers': None,
#                       'sp_monthly_listeners': None,
#                       'verified': False},
#                      {'cm_artist_score': 5,
#                       'id': 11150299,
#                       'image_url': None,
#                       'isni': None,
# ...

# %%
#Omah Lay's ID is 3578130
#Now checking his top countries on YT as of today (16.07.24) or the next possible date
res = Get('/api/artist/3578130/youtube-audience-stats?date=2024-07-16&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'male', 'weight': '70.95'},
#                               {'code': 'female', 'weight': '29.05'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '1.99',
#                                        'male': '2.22'},
#                                       {'code': '18-24',
#                                        'female': '16.09',
#                                        'male': '32.77'},
#                                       {'code': '25-34',
#                                        'female': '9.44',
#                                        'male': '31.94'},
#                                       {'code': '35-44',
#                                        'female': '1.30',
#                                        'male': '3.49'},
#                                       {'code': '45-64',
#                                        'female': '0.24',
# ...

# %%
omah24top = res.json()

omah24top["obj"]["top_countries"]
# Out:
# [{'name': 'Kenya', 'code': 'ke', 'percent': '16.11', 'subscribers': 320602},
#  {'name': 'United States',
#   'code': 'us',
#   'percent': '15.30',
#   'subscribers': 304410},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '10.98', 'subscribers': 218591},
#  {'name': 'France', 'code': 'fr', 'percent': '6.02', 'subscribers': 119821},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '5.13',
#   'subscribers': 102009},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '4.07', 'subscribers': 80959},
#  {'name': 'Uganda', 'code': 'ug', 'percent': '3.66', 'subscribers': 72863},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '3.42',
#   'subscribers': 68006},
#  {'name': 'Tanzania', 'code': 'tz', 'percent': '2.36', 'subscribers': 46956},
#  {'name': 'Canada', 'code': 'ca', 'percent': '2.12', 'subscribers': 42098},
#  {'name': 'Brazil', 'code': 'br', 'percent': '1.79', 'subscribers': 35622},
# ...

# %%
#Now looking for Wizkid's ID

res = Get('/api/search?q=Wizkid&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'albums': [{'artist_name': ['Designer'],
#                      'cm_artist': [428882],
#                      'id': 2452992,
#                      'image_url': 'https://i.scdn.co/image/f554f3c1a2d1f66c661de39b359018f6d0eeb303',
#                      'label': 'Shot Out',
#                      'name': 'Wizkid'}],
#          'artists': [{'cm_artist_score': 94297,
#                       'id': 4390,
#                       'image_url': 'https://i.scdn.co/image/ab6761610000e5eb9050b61368975fda051cdc06',
#                       'isni': None,
#                       'name': 'Wizkid',
#                       'sp_followers': 5593716,
#                       'sp_monthly_listeners': 9315701,
#                       'verified': False},
#                      {'cm_artist_score': None,
#                       'id': 812501,
#                       'image_url': None,
#                       'isni': None,
#                       'name': 'WizKid',
# ...

# %%
#Wizkids ID is 4390
#Now checking his top countries on YT as of today (16.07.24) or the next possible date
res = Get('/api/artist/4390/youtube-audience-stats?date=2024-07-16&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# {'obj': {'audience_genders': [{'code': 'male', 'weight': '61.48'},
#                               {'code': 'female', 'weight': '38.52'}],
#          'audience_genders_per_age': [{'code': '13-17',
#                                        'female': '2.58',
#                                        'male': '2.41'},
#                                       {'code': '18-24',
#                                        'female': '20.04',
#                                        'male': '27.53'},
#                                       {'code': '25-34',
#                                        'female': '13.18',
#                                        'male': '27.65'},
#                                       {'code': '35-44',
#                                        'female': '2.13',
#                                        'male': '3.22'},
#                                       {'code': '45-64',
#                                        'female': '0.60',
# ...

# %%
wizkid24top = res.json()

wizkid24top["obj"]["top_countries"]
# Out:
# [{'name': 'United States',
#   'code': 'us',
#   'percent': '19.50',
#   'subscribers': 596623},
#  {'name': 'Nigeria', 'code': 'ng', 'percent': '9.95', 'subscribers': 304460},
#  {'name': 'Kenya', 'code': 'ke', 'percent': '7.64', 'subscribers': 233728},
#  {'name': 'United Kingdom',
#   'code': 'gb',
#   'percent': '6.53',
#   'subscribers': 199900},
#  {'name': 'France', 'code': 'fr', 'percent': '6.33', 'subscribers': 193750},
#  {'name': 'South Africa',
#   'code': 'za',
#   'percent': '4.22',
#   'subscribers': 129165},
#  {'name': 'Ghana', 'code': 'gh', 'percent': '4.02', 'subscribers': 123015},
#  {'name': 'Tanzania', 'code': 'tz', 'percent': '3.42', 'subscribers': 104563},
#  {'name': 'Uganda', 'code': 'ug', 'percent': '2.71', 'subscribers': 83036},
#  {'name': 'Canada', 'code': 'ca', 'percent': '2.41', 'subscribers': 73810},
#  {'name': 'Italy', 'code': 'it', 'percent': '1.61', 'subscribers': 49204},
# ...

# %%
#Now looking for Tempoe's ID

res = Get('/api/search?q=Tempoe&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# artists in 2023:   Tempoe, Libianca
# Out:
# {'obj': {'albums': [{'artist_name': ['Amster Gank', 'Amster Gank'],
#                      'cm_artist': [6243470, 5755742],
#                      'id': 17560988,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b273da6878c2944ad9520232d292',
#                      'label': 'Amster Gank',
#                      'name': 'Tempoe'},
#                     {'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37220751,
#                      'image_url': 'https://is1-ssl.mzstatic.com/image/thumb/Music126/v4/7c/00/c9/7c00c99e-a633-2697-ab69-672e5c59df5b/0.jpg/160x160bb.jpg',
#                      'label': None,
#                      'name': 'Tempo - Single'},
#                     {'artist_name': [],
#                      'cm_artist': [],
#                      'id': 37192224,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b273707fb4bc60a064e25a9300f5',
#                      'label': None,
# ...

# %%
curl -H "Authorization: Bearer [KhFh4xkTLk5BSE9wwbambqba6OfkPhPcjyBmiVyl98o3wvw6LJF4EvFr5f2V3yrj]" https://api.chartmetric.com/api/artist/9190388/youtube-audience-stats?date=2022-03-28&geoOnly=false
# Out:
#   Cell In[56], line 1
#     curl -H "Authorization: Bearer [KhFh4xkTLk5BSE9wwbambqba6OfkPhPcjyBmiVyl98o3wvw6LJF4EvFr5f2V3yrj]" https://api.chartmetric.com/api/artist/9190388/youtube-audience-stats?date=2022-03-28&geoOnly=false
#                                                                                                                                                                                        ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
#Tempoe's ID is 9190388
#Now checking his top countries on YT as of today (16.07.24) or the next possible date
res = Get('/api/artist/9190388/youtube-audience-stats')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# ERROR: received a 404 instead of 200 from /api/artist/:id
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
#Now looking for Libianca's ID

res = Get('/api/search?q=Libianca&limit=3')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# artists in 2023:   Tempoe, Libianca
# Out:
# {'obj': {'albums': [{'artist_name': ['Sam Arrag'],
#                      'cm_artist': [6068920],
#                      'id': 26063801,
#                      'image_url': 'https://i.scdn.co/image/ab67616d0000b273f01965d09cb5505e10716285',
#                      'label': 'Covers',
#                      'name': 'Libianca'}],
#          'artists': [{'cm_artist_score': 25737,
#                       'id': 3976019,
#                       'image_url': 'https://i.scdn.co/image/ab676161000051748c079aacb406ccea5708a0fc',
#                       'isni': None,
#                       'name': 'Libianca',
#                       'sp_followers': 477300,
#                       'sp_monthly_listeners': 7239538,
#                       'verified': False},
#                      {'cm_artist_score': 0,
#                       'id': 10793007,
#                       'image_url': None,
#                       'isni': None,
#                       'name': 'Libianca',
# ...

# %%
#Libianca's ID is 26063801
#Now checking her top countries on YT as of today (16.07.24) or the next possible date
res = Get('/api/artist/26063801/youtube-audience-stats?date=2021-07-16&geoOnly=false')
if res.status_code != 200:
    print(f'ERROR: received a {res.status_code} instead of 200 from /api/artist/:id')
    exit(1)

pprint(res.json())
# Out:
# ERROR: received a 404 instead of 200 from /api/artist/:id
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
#Chartmetric does seem not to have YT Data on Libianca and Tempoe?

# %%
#Scraping festival lineups
#Starting with Glastonbury 2022

from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.glastonburyfestivals.co.uk/line-up/line-up-2022/?artist"
html = requests.get(url).text

# %%
soup = BeautifulSoup(html)

# %%
#How to select just the text?

soup.select(".title")
# Out:
# [<span class="title">A COLLECTION OF RADICAL FILMS CURATED BY SHANGRILART FEATURING : DR D-SUBVERTISER, REEL NEWS, DARREN CULLEN AND MANY MORE.</span>,
#  <span class="title">A COLLECTION OF RADICAL FILMS CURATED BY SHANGRILART FEATURING : DR D-SUBVERTISER, REEL NEWS, DARREN CULLEN AND MANY MORE.</span>,
#  <span class="title">A COLLECTION OF RADICAL FILMS CURATED BY SHANGRILART FEATURING : DR D-SUBVERTISER, REEL NEWS, DARREN CULLEN AND MANY MORE.</span>,
#  <span class="title">A COLLECTION OF RADICAL FILMS CURATED BY SHANGRILART FEATURING : DR D-SUBVERTISER, REEL NEWS, DARREN CULLEN AND MANY MORE.</span>,
#  <span class="title">A J LAMBERT</span>,
#  <span class="title">A LITTLE SOUND</span>,
#  <span class="title">A Q&amp;A WITH PAM AYRES</span>,
#  <span class="title">A-FUTURE</span>,
#  <span class="title">A.M.C &amp; PHANTOM</span>,
#  <span class="title">A.M.C FT PHANTOM</span>,
#  <span class="title">AAA BADBOY</span>,
#  <span class="title">AAA BADBOY</span>,
# ...

# %%
artistsGB22 = soup.select(".title")
GB22 = []
for title in artistsGB22:
    GB22.append(title.text)
    print(GB22)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
#Into a dataframe to drop the duplicates


for artist in GB22:
    artistBG_df = {
        "name": artist
    }
    GB22.append(artistBG_df)

artistsGB22

# artistBG_df = pd.DataFrame(GB22)

# artistBG_df
